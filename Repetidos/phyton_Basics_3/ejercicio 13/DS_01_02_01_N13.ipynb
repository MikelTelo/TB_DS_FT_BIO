# %% [markdown]
# ![TheBridge_logo_RGB_color.jpg](attachment:TheBridge_logo_RGB_color.jpg)

# %% [markdown]
# ![ejercicios.png](attachment:ejercicios.png)

# %% [markdown]
# ## PRACTICA OBLIGATORIA: COLECCIONES Y FUNCIONES

# %% [markdown]
# * La práctica obligatoria de esta unidad consiste varios ejercicios de programación libre a completar sobre Colecciones y Funciones. Descarga este notebook en tu ordenador y trabaja en local.
# * Recuerda que debes subirla a tu repositorio personal antes de la sesión en vivo para que puntúe adecuadamente y puedas participar en dicha sesión.
# * Recuerda también que no es necesario que esté perfecta, sólo es necesario que se vea el esfuerzo.
# * Esta práctica se resolverá en la sesión en vivo correspondiente y la solución se publicará en el repo del curso.

# %% [markdown]
# ### Contenidos

# %% [markdown]
# ## Ejercicio 1
# Eleva todos los elementos de la lista al cuadrado
# > ```ejer_2 = [1,2,3,4,5]```

# %%
ejer_2 = [1,2,3,4,5]
ejer_2_al_cuadrado = [i**2 for i in ejer_2]
print(ejer_2_al_cuadrado)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# ## Ejercicio 2
# Haz un programa que detecte todos los duplicados de un elemento en una lista:
# * Utiliza una variable duplicado para asignarle el valor del elemento del que queremos encontrar todos sus duplicados.
# * El programa debe devolver todos los índices de los elementos duplicados.
# * Aplícalo para encontrar los duplicados de "un", "es" y "binario" de:
#
# >```ejer_3 = ["Un", "árbol", "binario", "es", "una", "estructura", "de", "un", "tipo", "particular", "a", "veces", "no", "es", "ni", "binario"]```

# %%
def find_duplicates(lst, element):
    indices = []
    element_lower = element.lower()
    for index, value in enumerate(lst):
        if value.lower() == element_lower:
            indices.append(index)
    return indices

ejer_3 = ["Un", "árbol", "binario", "es", "una", "estructura", "de", "un", "tipo", "particular", "a", "veces", "no", "es", "ni", "binario"]

# Buscar duplicados de "un"
duplicados_un = find_duplicates(ejer_3, "un")
print(f'Duplicados de "un": {duplicados_un}')

# Buscar duplicados de "es"
duplicados_es = find_duplicates(ejer_3, "es")
print(f'Duplicados de "es": {duplicados_es}')

# Buscar duplicados de "binario"
duplicados_binario = find_duplicates(ejer_3, "binario")
print(f'Duplicados de "binario": {duplicados_binario}')
# Out:
# Duplicados de "un": [0, 7]
# Duplicados de "es": [3, 13]
# Duplicados de "binario": [2, 15]

# %% [markdown]
# ## Ejercicio 3
# 1. ¿Cuántas veces se repite el 3 en la siguiente tupla?
# 2. Crea una tupla nueva con los elementos desde la posicion 5 a la 10.
# 3. ¿Cuántos elementos tiene la tupla `ejer_3`?
# > ```ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)```

# %%
ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)

num_tres = ejer_9.count(3)
print(f"El número 3 se repite {num_tres} veces en la tupla.")

nueva_tupla = ejer_9[5:11]
print(f"Tupla nueva desde la posición 5 a la 10: {nueva_tupla}")

ejer_3 = ("Un", "árbol", "binario", "es", "una", "estructura", "de", "un", "tipo", "particular", "a", "veces", "no", "es", "ni", "binario")

num_elementos = len(ejer_3)
print(f"La tupla ejer_3 tiene {num_elementos} elementos.")
# Out:
# El número 3 se repite 7 veces en la tupla.
# Tupla nueva desde la posición 5 a la 10: (3, 29, 45, 67, 78, 90)
# La tupla ejer_3 tiene 16 elementos.

# %% [markdown]
# ## Ejercicio 4
# Comprueba si el numero 60 esta en la tupla del ejercicio 3

# %%
ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)

# Comprobar si el número 60 está en la tupla
is_sixty_in_tuple = 60 in ejer_9

if is_sixty_in_tuple:
    print("El número 60 está en la tupla.")
else:
    print("El número 60 no está en la tupla.")
# Out:
# El número 60 no está en la tupla.

# %% [markdown]
# ## Ejercicio 5
# 1. Convierte la tupla del ejercicio 3 en una lista
# 2. Convierte la tupla del ejercicio 3 en un set
# 3. Convierte la tupla del ejercicio 3 en un diccionario. Usa también los indices

# %%
ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)
lista = list(ejer_9)
print(lista)  # Salida: [3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7]

ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)
conjunto = set(ejer_9)
print(conjunto)  # Salida: {2, 3, 4, 5, 6, 7, 9, 19, 20, 29, 45, 47, 67, 78, 90}

ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)
diccionario = {i: ejer_9[i] for i in range(len(ejer_9))}
print(diccionario)  
# Salida: {0: 3, 1: 20, 2: 3, 3: 47, 4: 19, 5: 3, 6: 29, 7: 45, 8: 67, 9: 78, 10: 90, 11: 3, 12: 3, 13: 5, 14: 2, 15: 4, 16: 7, 17: 9, 18: 4, 19: 2, 20: 4, 21: 3, 22: 3, 23: 4, 24: 6, 25: 7}
# Out:
# [3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7]
# {2, 3, 67, 5, 4, 7, 6, 9, 45, 78, 47, 19, 20, 90, 29}
# {0: 3, 1: 20, 2: 3, 3: 47, 4: 19, 5: 3, 6: 29, 7: 45, 8: 67, 9: 78, 10: 90, 11: 3, 12: 3, 13: 5, 14: 2, 15: 4, 16: 7, 17: 9, 18: 4, 19: 2, 20: 4, 21: 3, 22: 3, 23: 4, 24: 6, 25: 7}

# %% [markdown]
# ## Ejercicio 6
# Multiplica todos los valores del diccionario
# > ```ejer_6 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}```

# %%
# Diccionario dado
ejer_6 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}

# Inicializar el producto a 1
producto = 1

# Iterar sobre los valores del diccionario y multiplicar
for valor in ejer_6.values():
    producto *= valor

# Imprimir el resultado
print(producto)  # Salida: 52952960
# Out:
# 19326120

# %% [markdown]
# ## Ejercicio 7
#
# 1. Crea un diccionario que describa un libro, con los siguientes campos o claves: "titulo","autor","idioma original","año de publicación".
# 2. Crea un a lista, llamada librería.
# 3. Añade cuatro libros a tu elección a la librería.

# %%
# Ejemplo de un diccionario que describe un libro
libro_ejemplo = {
    "titulo": "1984",
    "autor": "George Orwell",
    "idioma original": "Inglés",
    "año de publicación": 1949
}

# Crear una lista vacía para almacenar libros
libreria = []

# Crear los diccionarios para cada libro
libro1 = {
    "titulo": "1984",
    "autor": "George Orwell",
    "idioma original": "Inglés",
    "año de publicación": 1949
}

libro2 = {
    "titulo": "Cien años de soledad",
    "autor": "Gabriel García Márquez",
    "idioma original": "Español",
    "año de publicación": 1967
}

libro3 = {
    "titulo": "El gran Gatsby",
    "autor": "F. Scott Fitzgerald",
    "idioma original": "Inglés",
    "año de publicación": 1925
}

libro4 = {
    "titulo": "Matar a un ruiseñor",
    "autor": "Harper Lee",
    "idioma original": "Inglés",
    "año de publicación": 1960
}

# Añadir los libros a la lista librería
libreria.append(libro1)
libreria.append(libro2)
libreria.append(libro3)
libreria.append(libro4)
print(libreria)
# Out:
# [{'titulo': '1984', 'autor': 'George Orwell', 'idioma original': 'Inglés', 'año de publicación': 1949}, {'titulo': 'Cien años de soledad', 'autor': 'Gabriel García Márquez', 'idioma original': 'Español', 'año de publicación': 1967}, {'titulo': 'El gran Gatsby', 'autor': 'F. Scott Fitzgerald', 'idioma original': 'Inglés', 'año de publicación': 1925}, {'titulo': 'Matar a un ruiseñor', 'autor': 'Harper Lee', 'idioma original': 'Inglés', 'año de publicación': 1960}]

# %% [markdown]
# ## Ejercicio 8
# Modifica los valores del idioma de todos los libros del ejercicio anterior para que sea "esperanto"

# %%
# Modificar el idioma de todos los libros a "esperanto"
for libro in libreria:
    libro["idioma original"] = "esperanto"

# Imprimir la librería para verificar los cambios
print(libreria)
# Out:
# [{'titulo': '1984', 'autor': 'George Orwell', 'idioma original': 'esperanto', 'año de publicación': 1949}, {'titulo': 'Cien años de soledad', 'autor': 'Gabriel García Márquez', 'idioma original': 'esperanto', 'año de publicación': 1967}, {'titulo': 'El gran Gatsby', 'autor': 'F. Scott Fitzgerald', 'idioma original': 'esperanto', 'año de publicación': 1925}, {'titulo': 'Matar a un ruiseñor', 'autor': 'Harper Lee', 'idioma original': 'esperanto', 'año de publicación': 1960}]

# %% [markdown]
# ## Ejercicio 9
# 1. Escribe un programa que dada una variable titulo busque los libros que hay en la librería con ese título. Si no se encuentra debe devolver el mensaje `Ese no lo tengo, ¿mola?`
# 2. Pruena que el programa con uno de tus libros y con otro que no contenga tu librería.

# %%
def buscar_libro(titulo):
    # Buscar en la librería el libro con el título dado
    for libro in libreria:
        if libro["titulo"] == titulo:
            return libro
    return "Ese no lo tengo, ¿mola?"

# Probar la función con un libro que está en la librería
titulo_a_buscar_1 = "Cien años de soledad"
resultado_1 = buscar_libro(titulo_a_buscar_1)
print(f"Buscar '{titulo_a_buscar_1}': {resultado_1}")

# Probar la función con un libro que no está en la librería
titulo_a_buscar_2 = "El código Da Vinci"
resultado_2 = buscar_libro(titulo_a_buscar_2)
print(f"Buscar '{titulo_a_buscar_2}': {resultado_2}")
# Out:
# Buscar 'Cien años de soledad': {'titulo': 'Cien años de soledad', 'autor': 'Gabriel García Márquez', 'idioma original': 'esperanto', 'año de publicación': 1967}
# Buscar 'El código Da Vinci': Ese no lo tengo, ¿mola?

# %% [markdown]
# ## Ejercicio 10
# Convierte el programa del ejercicio 2 en una función al que se le pase el valor a buscar como un argumento posicional

# %% [markdown]
# ## Ejercicio 11
# Convierte el programa del ejercicio 9 en una función al que se le pasen como argumentos la librería, posicional, y el título, argumento keyword con valor "ninguno", por defecto.

# %% [markdown]
# ## Ejercicio 12
# Solicitar al usuario que ingrese su dirección email. Imprimir un mensaje indicando si la dirección es válida o no, valiéndose de una función para decidirlo. Una dirección se considerará válida si contiene el símbolo "@".

# %% [markdown]
# ## Ejercicio 13
# Escribe una función que compruebe si un DNI es válido, devolviendo `True` en caso afirmativo.
# En primer lugar, el DNI debe tener entre 7 y 8 dígitos numéricos.
# Para saber si la letra del DNI es correcta puedes utilizar el siguiente fragmento de código:
# >```Python
# >DNI= 55555555
# >palabra='TRWAGMYFPDXBNJZSQVHLCKE'
# >print('La letra del DNI es: ', palabra[DNI%23])
# >````
